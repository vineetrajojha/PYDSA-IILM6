# %% [markdown]
# illapanda coding challenge
#
# 1. function inside function = method
# 2. class add:
#         def add(a,b):
#             return a + b
#     here: def = class member / entity

# %%
#leap year

year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(year, "is a leap year.")
else:    
    print(year, "is not a leap year.")
